# %%
# %run eda_analysis.ipynb
# %run preprocessing_loader_v2.ipynb
# Out:
# Requirement already satisfied: kagglehub in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.3.13)
# Requirement already satisfied: packaging in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (23.2)
# Requirement already satisfied: pyyaml in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->kagglehub) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Path to dataset files: C:\Users\maxim\.cache\kagglehub\datasets\kartik2112\fraud-detection\versions\1
# test columns :
#
#  Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')
#
#
#  train columns :
#
#  Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')
#
#  TRAIN: 1,296,675 rows × 22 columns
#  TEST: 555,719 rows × 22 columns
#
#  Columns:
# ['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long', 'is_fraud']
#
# ================================================================================
# 2. DATA QUALITY
# ================================================================================
#
#  Missing values - TRAIN: 0, TEST: 0
#  Duplicates - TRAIN: 0, TEST: 0
#
#  Data types:
# object     12
# int64       5
# float64     5
# Name: count, dtype: int64
#
# ================================================================================
# 3. CLASS IMBALANCE - TARGET 'is_fraud'
# ================================================================================
#
#  TRAIN:
#    Legitimate (0): 1,289,169 (99.421%)
#    Fraud (1): 7,506 (0.579%)
#    Imbalance ratio: 172:1
#
#  TEST:
#    Legitimate (0): 553,574 (99.614%)
#    Fraud (1): 2,145 (0.386%)
#    Imbalance ratio: 258:1
# ================================================================================
# 4. KEY FEATURES
# ================================================================================
#
#  Feature types:
#    Numeric: 9
#    Categorical: 12
#
#  Amount (amt) statistics:
#    Mean: $70.35
#    Median: $47.52
#    Std: $160.32
#    Range: $1.00 - $28948.90
#
#    By class:
#    Legitimate: $67.67
#    Fraud: $531.32
#
#  Time period:
#    From: 2019-01-01 00:00:18
#    To: 2020-06-21 12:13:37
#    Duration: 537 days
#
# ================================================================================
# 5. DESCRIPTIVE STATISTICS
# ================================================================================
#
#  Numeric features summary:
#                     mean           std           min           max
# cc_num      4.171920e+17  1.308806e+18  6.041621e+10  4.992346e+18
# amt         7.035104e+01  1.603160e+02  1.000000e+00  2.894890e+04
# zip         4.880067e+04  2.689322e+04  1.257000e+03  9.978300e+04
# lat         3.853762e+01  5.075808e+00  2.002710e+01  6.669330e+01
# long       -9.022634e+01  1.375908e+01 -1.656723e+02 -6.795030e+01
# city_pop    8.882444e+04  3.019564e+05  2.300000e+01  2.906700e+06
# unix_time   1.349244e+09  1.284128e+07  1.325376e+09  1.371817e+09
# merch_lat   3.853734e+01  5.109788e+00  1.902779e+01  6.751027e+01
# merch_long -9.022646e+01  1.377109e+01 -1.666712e+02 -6.695090e+01
#
# ================================================================================
# 6. KEY INSIGHTS & NEXT STEPS
# ================================================================================
#
#  KEY FINDINGS:
#    1. Severe class imbalance: ~172:1 ratio
#    2. 9 numeric features, 12 categorical
#    3. High cardinality in merchant, job → Need encoding strategy
#    4. Temporal data available for feature engineering
#    5. No missing values (excellent data quality)
#
#  PREPROCESSING ROADMAP:
#    1. Drop PII: cc_num, first, last, street, trans_num
#    2. Temporal features: extract hour, day, day_of_week from trans_date_trans_time
#    3. Encode categoricals:
#       • Low cardinality (gender, state): One-Hot or Label Encoding
#       • High cardinality (category, merchant, job): Target Encoding
#    4. Scale numeric features: amt, lat, long, city_pop
#    5. Feature engineering: customer-merchant distance, age from dob
#    6. Handle imbalance: SMOTE, class_weight, or undersampling
#
#  MODELING STRATEGY:
#    • Validation: StratifiedKFold (5-fold)
#    • Metrics: F1-Score (primary), PR-AUC, ROC-AUC
#    • Models: Random Forest, Gradient Boosting, XGBoost
#    • Optimize threshold based on business cost (FP vs FN)
#
# ================================================================================
#  EXPLORATION COMPLETED - Ready for preprocessing!
# ================================================================================
# Requirement already satisfied: kagglehub in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.3.13)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: packaging in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (23.2)
# Requirement already satisfied: pyyaml in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\maxim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->kagglehub) (0.4.6)
# Path to dataset files: C:\Users\maxim\.cache\kagglehub\datasets\kartik2112\fraud-detection\versions\1
# test columns :
#
#  Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')
#
#
#  train columns :
#
#  Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')
#
#  TRAIN: 1,296,675 rows × 22 columns
#  TEST: 555,719 rows × 22 columns
#
#  Columns:
# ['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long', 'is_fraud']
#
# ================================================================================
# 2. DATA QUALITY
# ================================================================================
#
#  Missing values - TRAIN: 0, TEST: 0
#  Duplicates - TRAIN: 0, TEST: 0
#
#  Data types:
# object     12
# int64       5
# float64     5
# Name: count, dtype: int64
#
# ================================================================================
# 3. CLASS IMBALANCE - TARGET 'is_fraud'
# ================================================================================
#
#  TRAIN:
#    Legitimate (0): 1,289,169 (99.421%)
#    Fraud (1): 7,506 (0.579%)
#    Imbalance ratio: 172:1
#
#  TEST:
#    Legitimate (0): 553,574 (99.614%)
#    Fraud (1): 2,145 (0.386%)
#    Imbalance ratio: 258:1
# ================================================================================
# 4. KEY FEATURES
# ================================================================================
#
#  Feature types:
#    Numeric: 9
#    Categorical: 12
#
#  Amount (amt) statistics:
#    Mean: $70.35
#    Median: $47.52
#    Std: $160.32
#    Range: $1.00 - $28948.90
#
#    By class:
#    Legitimate: $67.67
#    Fraud: $531.32
#
#  Time period:
#    From: 2019-01-01 00:00:18
#    To: 2020-06-21 12:13:37
#    Duration: 537 days
#
# ================================================================================
# 5. DESCRIPTIVE STATISTICS
# ================================================================================
#
#  Numeric features summary:
#                     mean           std           min           max
# cc_num      4.171920e+17  1.308806e+18  6.041621e+10  4.992346e+18
# amt         7.035104e+01  1.603160e+02  1.000000e+00  2.894890e+04
# zip         4.880067e+04  2.689322e+04  1.257000e+03  9.978300e+04
# lat         3.853762e+01  5.075808e+00  2.002710e+01  6.669330e+01
# long       -9.022634e+01  1.375908e+01 -1.656723e+02 -6.795030e+01
# city_pop    8.882444e+04  3.019564e+05  2.300000e+01  2.906700e+06
# unix_time   1.349244e+09  1.284128e+07  1.325376e+09  1.371817e+09
# merch_lat   3.853734e+01  5.109788e+00  1.902779e+01  6.751027e+01
# merch_long -9.022646e+01  1.377109e+01 -1.666712e+02 -6.695090e+01
#
# ================================================================================
# 6. KEY INSIGHTS & NEXT STEPS
# ================================================================================
#
#  KEY FINDINGS:
#    1. Severe class imbalance: ~172:1 ratio
#    2. 9 numeric features, 12 categorical
#    3. High cardinality in merchant, job → Need encoding strategy
#    4. Temporal data available for feature engineering
#    5. No missing values (excellent data quality)
#
#  PREPROCESSING ROADMAP:
#    1. Drop PII: cc_num, first, last, street, trans_num
#    2. Temporal features: extract hour, day, day_of_week from trans_date_trans_time
#    3. Encode categoricals:
#       • Low cardinality (gender, state): One-Hot or Label Encoding
#       • High cardinality (category, merchant, job): Target Encoding
#    4. Scale numeric features: amt, lat, long, city_pop
#    5. Feature engineering: customer-merchant distance, age from dob
#    6. Handle imbalance: SMOTE, class_weight, or undersampling
#
#  MODELING STRATEGY:
#    • Validation: StratifiedKFold (5-fold)
#    • Metrics: F1-Score (primary), PR-AUC, ROC-AUC
#    • Models: Random Forest, Gradient Boosting, XGBoost
#    • Optimize threshold based on business cost (FP vs FN)
#
# ================================================================================
#  EXPLORATION COMPLETED - Ready for preprocessing!
# ================================================================================
#  Dropped 5 columns
# test columns :
#
#  Index(['trans_date_trans_time', 'merchant', 'category', 'amt', 'gender',
#        'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob',
#        'unix_time', 'merch_lat', 'merch_long', 'is_fraud', 'trans_datetime'],
#       dtype='object')
#
#
#  train columns :
#
#  Index(['trans_date_trans_time', 'merchant', 'category', 'amt', 'gender',
#        'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob',
#        'unix_time', 'merch_lat', 'merch_long', 'is_fraud', 'trans_datetime'],
#       dtype='object')
#
#  Fraud transaction by hour:
# hour
# 22    1931
# 23    1904
# 1      658
# 0      635
# 2      625
# dtype: int64
#
#  Distribution of 'hour' (fraud vs legitimate):
#
# Fraud transactions by hour:
# hour
# 22    1931
# 23    1904
# 1      658
# 0      635
# 2      625
# dtype: int64
#
#  Fraud rate by time period:
#    Morning: 334 frauds / 295,717 transactions = 0.113%
#    Afternoon: 466 frauds / 392,023 transactions = 0.119%
#    Evening: 2,229 frauds / 329,172 transactions = 0.677%
#    Night: 4,477 frauds / 279,763 transactions = 1.600%
#
#  Distance statistics (TRAIN):
#    Mean: 84.99 km
#    Median: 88.61 km
#    Std Dev: 31.61 km
#    Min: 0.03 km
#    Max: 156.88 km
#   ligne 2: 30.22641496342932
#  Merchant : fraud_Heller, Gutmann and Zieme
#
#  Distance percentiles:
#    25th percentile: 62.71 km
#    50th percentile: 88.61 km
#    75th percentile: 108.51 km
#    90th percentile: 123.80 km
#    95th percentile: 133.03 km
#    99th percentile: 146.07 km
#
#  Distance by class:
#
#    Legitimate transactions:
#       Mean: 84.99 km
#       Median: 88.61 km
#       75th percentile: 108.51 km
#       95th percentile: 133.03 km
#
#    Fraud transactions:
#       Mean: 85.17 km
#       Median: 88.46 km
#       75th percentile: 108.38 km
#       95th percentile: 132.70 km
#
#  Distance categories distribution:
#    Very Close (<10 km): 44 frauds / 8,224 = 0.535%
#    Close (10-50 km): 1,108 frauds / 198,280 = 0.559%
#    Regional (50-200 km): 6,354 frauds / 1,090,171 = 0.583%
#    Far (200-500 km): 0 frauds / 0 = 0.000%
#    Very Far (>500 km): 0 frauds / 0 = 0.000%
#
# ================================================================================
# 4. CREATING VISUALIZATIONS
# ================================================================================
#
#  Visualization saved: geographic_distance_analysis.png
#  What we created:
#    • distance_km: Euclidean distance between customer and merchant
#
#  Key findings:
#    • Mean distance (Legitimate): 84.99 km
#    • Mean distance (Fraud): 85.17 km
#
#  Current shapes:
#    TRAIN: (1296675, 25)
#    TEST: (555719, 25)
# Age statistics :
# count    1.296675e+06
# mean     4.602318e+01
# std      1.734874e+01
# min      1.800000e+01
# 25%      3.259959e+01
# 50%      4.396988e+01
# 75%      5.707050e+01
# max      9.563860e+01
# Name: age, dtype: float64
# count    555719.000000
# mean         46.905700
# std          17.400883
# min          18.000000
# 25%          33.448323
# 50%          44.908966
# 75%          58.056126
# max          96.169747
# Name: age, dtype: float64
#
# Distribution :
# age_category
# Adults (25-50)    718038
# Old (>50)         456949
# Young (18-25)     121688
# Name: count, dtype: int64
# age_category
# Adults (25-50)    304430
# Old (>50)         204922
# Young (18-25)      46367
# Name: count, dtype: int64
#
# Mean age for each category :
#            mean  median    std
# is_fraud
# 0         46.01   43.96  17.34
# 1         48.82   47.80  18.83
#            mean  median    std
# is_fraud
# 0         46.90   44.90  17.40
# 1         48.98   47.82  17.63
#
# Fraud rate by category :
#                 mean
# age_category
# Adults (25-50)  0.47
# Old (>50)       0.74
# Young (18-25)   0.63
#  Categorical columns : 7
#  •merchant: 693 unique values
#  •category: 14 unique values
#  •gender: 2 unique values
#  •city: 894 unique values
#  •state: 51 unique values
#  •job: 494 unique values
#  •age_category: 3 unique values
#
#  Gender encoded:
# F -> 0
# M -> 1
#
#  After encoding:
# gender
# 0    709863
# 1    586812
# Name: count, dtype: int64
#
#  Split complété (avant encodage cible):
#    Train full: (1037340, 25) - pour encodage et training
#    Validation: (259335, 25) - pour tuning
#    Test: (555719, 26) - final eval (inchangé)
#
#  Vérif distribution classes:
#    Train full: 6,005 fraudes / 1,037,340 = 0.579%
#    Val: 1,501 fraudes / 259,335 = 0.579%
#    Test: 2,145 fraudes / 555,719 = 0.386%
#     Attention: Légères différences
#
#  Split complété (avant encodage cible):
#    Train full: (1037340, 25) - pour encodage et training
#    Validation: (259335, 25) - pour tuning
#    Test: (555719, 26) - final eval (inchangé)
#
#  Vérif distribution classes:
#    Train full: 6,005 fraudes / 1,037,340 = 0.579%
#    Val: 1,501 fraudes / 259,335 = 0.579%
#    Test: 2,145 fraudes / 555,719 = 0.386%
#     Attention: Légères différences
#    One-hot states aligné: 51 cols
#
#  5 colonnes catégorielles restantes:
#    • merchant: 693 uniques
#    • category: 14 uniques
#    • city: 894 uniques
#    • job: 494 uniques
#    • age_category: 3 uniques
#
#  Target Encoding sur restantes...
#
#  X_test défini et aligné:
#    Shape: (555719, 75)
#    Colonnes: 75 (match train_full)
#    Exemples: ['amt', 'gender', 'zip', 'lat', 'long']
#    y_test: (555719,) - 2,145 fraudes (0.386%)
#
#  Check leakage: Taux corrélation encoded vs target (sur train_full)
#    merchant_encoded: corr = 0.0742
#    category_encoded: corr = 0.0706
#    city_encoded: corr = 0.2793
#
#  Drop 2 colonnes datetime sur train_full:
#     trans_datetime
#     dob_datetime
#     Datetimes droppés sur tous les sets
#
#  Convert 51 bools → int sur train_full:
#     51 colonnes converties (bool → int)
#
#  Types finaux (sur train_full):
# int32      57
# float64    12
# int64       4
# Name: count, dtype: int64
#
#  SUCCESS: Toutes colonnes numériques !
#
#  Shapes après corrections:
#    X_train_full: (1037340, 73)
#    X_val: (259335, 73)
#    X_test: (555719, 73)
#     Colonnes alignées OK
#    Merchants with 'fraud' in name: 1296675
#     WARNING: Potential data leakage!
#
#  Séparation features/target après encodage:
#    X_train_full: (1037340, 73)
#    y_train_full: (1037340,)
#    X_val: (259335, 73)
#    X_test: (555719, 75)
#    Colonnes binaires (pas de scaling): 53
#    Exemples: ['gender', 'is_weekend', 'state_AK', 'state_AL', 'state_AR']
#
#    Colonnes à scaler: 20
#    Exemples: ['amt', 'zip', 'lat', 'long', 'city_pop', 'unix_time', 'merch_lat', 'merch_long', 'hour', 'day_of_week']
#
#  Avant scaling (échantillon):
#            amt      lat        age  distance_km
# 509059   51.71  44.6087  28.177960    40.012744
# 395295   13.78  31.9290  48.626968    80.286202
# 536531  961.26  48.3400  34.959617    91.705535
#
#  Fit StandardScaler sur TRAIN_FULL...
#
#  Après scaling (même échantillon):
#              amt       lat       age  distance_km
# 509059 -0.118626  1.195429 -1.028601    -1.423264
# 395295 -0.360128 -1.302040  0.149841    -0.148675
# 536531  5.672535  1.930369 -0.637785     0.212729
#
#  Vérif scaling (~0 mean, ~1 std sur train_full):
#    amt: mean=-0.000000, std=1.000000
#    lat: mean=-0.000000, std=1.000000
#    age: mean=0.000000, std=1.000000
#    distance_km: mean=0.000000, std=1.000000
#
#  The Problem:
#    Current ratio: ~172:1 (legitimate:fraud)
#    Without balancing:
#    • Model will predict 'legitimate' for everything
#    • Accuracy = 99.4% but 0 frauds detected!
#    • Useless in production
#
#  Solution: SMOTE (Synthetic Minority Over-sampling Technique)
#    • Creates synthetic fraud examples by interpolation
#    • Interpolates between existing fraud transactions
#    • sampling_strategy=0.3 → target ratio 3:1 (not 1:1, too artificial)
#
#  CRITICAL RULES:
#    1. Apply SMOTE ONLY on train_full (NOT on validation/test!)
#    2. Never touch validation/test sets (data leakage!)
#    3. Validation/test must reflect real-world distribution
#
#  BEFORE SMOTE:
#    Class 0: 1,031,335
#    Class 1: 6,005
#    Ratio: 171.7:1
#
#  Applying SMOTE...
#
#  AFTER SMOTE:
#    Class 0 (legitimate): 1,031,335
#    Class 1 (fraud):      309,400
#    Ratio: 3.3:1
#
#  Size changes:
#    Before: 1,037,340 samples
#    After:  1,340,735 samples
#    Added:  303,395 synthetic frauds

# %% [markdown]
# # Modules

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import (f1_score, precision_score, recall_score,roc_auc_score,average_precision_score,confusion_matrix,classification_report, accuracy_score)
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import optuna

# %% [markdown]
# # Gradient Boosting Classifier

# %%
xgb = XGBClassifier(
    n_estimators=100,       # nombre d’arbres
    learning_rate=0.1,      # taux d’apprentissage
    max_depth=3,            # profondeur max des arbres
    random_state=42
)

# %% [markdown]
# ---

# %% [markdown]
# # Without SMOTE and without optimization

# %% [markdown]
# ---

# %% [markdown]
# # Training

# %%
X_train = X_train_full
y_train = y_train_full

# Calculate scale_pos_weight
scale = (y_train == 0).sum() / (y_train == 1).sum()
print(f"Class imbalance ratio : {scale:.1f}:1")
print(f"scale_pos_weight: {scale:.1f}")
# Out:
# Class imbalance ratio : 171.7:1
# scale_pos_weight: 171.7

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# # Predictions

# %%
X_test = X_val
y_test = y_val

# %%
y_pred = xgb.predict(X_test)

# %% [markdown]
# # Evaluate

# %%
acc = accuracy_score(y_test, y_pred)
print(f"✅ Accuracy du Gradient Boosting : {acc:.4f}\n")


print("📊 Report of classifier :")
y_pred_base_new = xgb.predict(X_test)
y_pred_proba_base_new = xgb.predict_proba(X_test)[:,1]

print(f"F1-Score:          {f1_score(y_test, y_pred_base_new)*100:.4f} %")
print(f"Precision:         {precision_score(y_test, y_pred_base_new)*100:.4f} %")
print(f"Recall:            {recall_score(y_test, y_pred_base_new)*100:.4f} %")
print(f"ROC-AUC:           {roc_auc_score(y_test, y_pred_proba_base_new)*100:.4f} %")
print(f"PR-AUC:            {average_precision_score(y_test, y_pred_proba_base_new)*100:.4f} %")
# Out:
# ✅ Accuracy du Gradient Boosting : 0.9976
#
# 📊 Report of classifier :
# F1-Score:          75.3226 %
# Precision:         91.1932 %
# Recall:            64.1572 %
# ROC-AUC:           98.3757 %
# PR-AUC:            79.8786 %

# %% [markdown]
# # Confusion Matrix

# %%
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Matrice de confusion - Gradient Boosting")
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Without SMOTE and with optimization

# %% [markdown]
# ---

# %%
def objective(trial):
    # Espace de recherche des hyperparamètres
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 2, 5),
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 2, 7),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 20),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
    }
    
    # Modèle
    model = XGBClassifier(**params, random_state=42)

    # Validation croisée pour évaluer la performance moyenne
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')

    return scores.mean()  # objectif : maximiser la précision moyenne

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=15, show_progress_bar=True)

print("Nombre d’essais :", len(study.trials))
print("Meilleur score :", study.best_value)
print("Meilleurs hyperparamètres :", study.best_params)
# Out:
# [I 2025-10-19 21:09:54,415] A new study created in memory with name: no-name-cb3be665-b273-4d57-bd74-c45f3a24cd44
#   0%|          | 0/15 [00:00<?, ?it/s]
# [I 2025-10-19 21:10:04,336] Trial 0 finished with value: 0.9971369078604893 and parameters: {'n_estimators': 5, 'learning_rate': 0.0967383244110492, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 18, 'subsample': 0.5200058337839291}. Best is trial 0 with value: 0.9971369078604893.
# [I 2025-10-19 21:10:13,602] Trial 1 finished with value: 0.994211155455299 and parameters: {'n_estimators': 4, 'learning_rate': 0.0010471211105051456, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 11, 'subsample': 0.8085749915175497}. Best is trial 0 with value: 0.9971369078604893.
# [I 2025-10-19 21:10:23,613] Trial 2 finished with value: 0.994211155455299 and parameters: {'n_estimators': 5, 'learning_rate': 0.0057931618309731885, 'max_depth': 2, 'min_samples_split': 13, 'min_samples_leaf': 1, 'subsample': 0.8207767414915927}. Best is trial 0 with value: 0.9971369078604893.
# [I 2025-10-19 21:10:33,789] Trial 3 finished with value: 0.9974878053482946 and parameters: {'n_estimators': 5, 'learning_rate': 0.1777866374362748, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 3, 'subsample': 0.5515889254436173}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:10:42,515] Trial 4 finished with value: 0.994211155455299 and parameters: {'n_estimators': 2, 'learning_rate': 0.007538054869769112, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 18, 'subsample': 0.5124110366960964}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:10:51,588] Trial 5 finished with value: 0.994211155455299 and parameters: {'n_estimators': 4, 'learning_rate': 0.0031666676871273404, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 8, 'subsample': 0.9872843180192161}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:11:00,895] Trial 6 finished with value: 0.994211155455299 and parameters: {'n_estimators': 5, 'learning_rate': 0.007514659210952776, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 5, 'subsample': 0.6943535659792085}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:11:09,727] Trial 7 finished with value: 0.9966790059189851 and parameters: {'n_estimators': 3, 'learning_rate': 0.12665424648709464, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 3, 'subsample': 0.5247600684171381}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:11:18,564] Trial 8 finished with value: 0.9958952705959474 and parameters: {'n_estimators': 3, 'learning_rate': 0.08049399224507099, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 18, 'subsample': 0.5998658530190515}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:11:27,924] Trial 9 finished with value: 0.994211155455299 and parameters: {'n_estimators': 2, 'learning_rate': 0.002398437402167816, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 7, 'subsample': 0.7749523580418569}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:11:39,421] Trial 10 finished with value: 0.9942130834634739 and parameters: {'n_estimators': 4, 'learning_rate': 0.029148439544289865, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 11, 'subsample': 0.6522026416172071}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:11:50,928] Trial 11 finished with value: 0.9972458403223629 and parameters: {'n_estimators': 5, 'learning_rate': 0.26992952842293155, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 15, 'subsample': 0.5942921207311329}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:12:03,424] Trial 12 finished with value: 0.9971802880444214 and parameters: {'n_estimators': 5, 'learning_rate': 0.2927315287854738, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 14, 'subsample': 0.6073306583998521}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:12:15,572] Trial 13 finished with value: 0.9967204580947422 and parameters: {'n_estimators': 5, 'learning_rate': 0.2502181867634006, 'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 14, 'subsample': 0.6991179654190013}. Best is trial 3 with value: 0.9974878053482946.
# [I 2025-10-19 21:12:28,480] Trial 14 finished with value: 0.9965507933753639 and parameters: {'n_estimators': 4, 'learning_rate': 0.05082468817311661, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 15, 'subsample': 0.5819252400324955}. Best is trial 3 with value: 0.9974878053482946.
# Nombre d’essais : 15
# Meilleur score : 0.9974878053482946
# Meilleurs hyperparamètres : {'n_estimators': 5, 'learning_rate': 0.1777866374362748, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 3, 'subsample': 0.5515889254436173}

# %%
best_model = XGBClassifier(**study.best_params, random_state=42)
best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

print("\n✅ Rapport de classification :\n", classification_report(y_test, y_pred))
print("✅ Matrice de confusion :\n", confusion_matrix(y_test, y_pred))
print("✅ Précision :", accuracy_score(y_test, y_pred))
# Out:
# ✅ Rapport de classification :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    257834
#            1       0.86      0.69      0.76      1501
#
#     accuracy                           1.00    259335
#    macro avg       0.93      0.84      0.88    259335
# weighted avg       1.00      1.00      1.00    259335
#
# ✅ Matrice de confusion :
#  [[257661    173]
#  [   470   1031]]
# ✅ Précision : 0.9975205814872655

# %%
acc = accuracy_score(y_test, y_pred)
print(f"✅ Accuracy du Gradient Boosting : {acc:.4f}\n")


print("📊 Report of classifier :")
y_pred_base_new = xgb.predict(X_test)
y_pred_proba_base_new = xgb.predict_proba(X_test)[:,1]

print(f"F1-Score:          {f1_score(y_test, y_pred_base_new)*100:.4f} %")
print(f"Precision:         {precision_score(y_test, y_pred_base_new)*100:.4f} %")
print(f"Recall:            {recall_score(y_test, y_pred_base_new)*100:.4f} %")
print(f"ROC-AUC:           {roc_auc_score(y_test, y_pred_proba_base_new)*100:.4f} %")
print(f"PR-AUC:            {average_precision_score(y_test, y_pred_proba_base_new)*100:.4f} %")
# Out:
# ✅ Accuracy du Gradient Boosting : 0.9975
#
# 📊 Report of classifier :
# F1-Score:          75.3226 %
# Precision:         91.1932 %
# Recall:            64.1572 %
# ROC-AUC:           98.3757 %
# PR-AUC:            79.8786 %

# %%
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Matrice de confusion - Gradient Boosting")
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # With SMOTE and without optimization

# %% [markdown]
# ---

# %%
X_train_smote = X_train_resampled
y_train_smote = y_train_resampled

# %%
xgb.fit(X_train_smote, y_train_smote)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# # Predictions

# %%
print(f"\n BEFORE SMOTE:")
print(f"   Class 0 (legitimate): {(y_train == 0).sum():,}")
print(f"   Class 1 (fraud):      {(y_train == 1).sum():,}")
print(f"   Ratio: {(y_train == 0).sum() / (y_train == 1).sum():.1f}:1")

print(f"\n Size changes:")
print(f"   Before: {X_train.shape[0]:,} samples")
print(f"   After:  {X_train.shape[0]:,} samples")
print(f"   Added:  {X_train.shape[0] - X_train.shape[0]:,} synthetic frauds")

# Convert back to DataFrame (SMOTE returns numpy arrays)
X_train = pd.DataFrame(X_train, columns=X_train.columns)
y_train = pd.Series(y_train, name='is_fraud')
# Out:
#  BEFORE SMOTE:
#    Class 0 (legitimate): 1,031,335
#    Class 1 (fraud):      6,005
#    Ratio: 171.7:1
#
#  Size changes:
#    Before: 1,037,340 samples
#    After:  1,037,340 samples
#    Added:  0 synthetic frauds

# %%
print(f"\n AFTER SMOTE:")
print(f"   Class 0 (legitimate): {(y_train_smote == 0).sum():,}")
print(f"   Class 1 (fraud):      {(y_train_smote == 1).sum():,}")
print(f"   Ratio: {(y_train_smote == 0).sum() / (y_train_smote == 1).sum():.1f}:1")

print(f"\n Size changes:")
print(f"   Before: {X_train_smote.shape[0]:,} samples")
print(f"   After:  {X_train_smote.shape[0]:,} samples")
print(f"   Added:  {X_train_smote.shape[0] - X_train_smote.shape[0]:,} synthetic frauds")

# Convert back to DataFrame (SMOTE returns numpy arrays)
X_train_smote = pd.DataFrame(X_train_smote, columns=X_train_smote.columns)
y_train_smote = pd.Series(y_train_smote, name='is_fraud')
# Out:
#  AFTER SMOTE:
#    Class 0 (legitimate): 1,031,335
#    Class 1 (fraud):      309,400
#    Ratio: 3.3:1
#
#  Size changes:
#    Before: 1,340,735 samples
#    After:  1,340,735 samples
#    Added:  0 synthetic frauds

# %% [markdown]
# ---

# %% [markdown]
# # With SMOTE and with optimization

# %% [markdown]
# ---

# %%
def objective(trial):
    # Espace de recherche des hyperparamètres
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 2, 5),
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 2, 7),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 20),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
    }
    
    # Modèle
    model = XGBClassifier(**params, random_state=42)

    # Validation croisée pour évaluer la performance moyenne
    scores = cross_val_score(model, X_train_smote, y_train_smote, cv=5, scoring='accuracy')

    return scores.mean()  # objectif : maximiser la précision moyenne

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=15, show_progress_bar=True)

print("Nombre d’essais :", len(study.trials))
print("Meilleur score :", study.best_value)
print("Meilleurs hyperparamètres :", study.best_params)
# Out:
# [I 2025-10-19 21:12:41,500] A new study created in memory with name: no-name-f4e9c496-5ae7-4079-993c-a41a570030c1
#   0%|          | 0/15 [00:00<?, ?it/s]
# [I 2025-10-19 21:12:57,432] Trial 0 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 4, 'learning_rate': 0.0012493381427788823, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 8, 'subsample': 0.5404022451417223}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:13:11,795] Trial 1 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 3, 'learning_rate': 0.0013700496402967311, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 15, 'subsample': 0.5068926027745321}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:13:26,463] Trial 2 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 2, 'learning_rate': 0.006535535049226517, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 20, 'subsample': 0.9006672506592477}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:13:40,572] Trial 3 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 3, 'learning_rate': 0.0024734671851340787, 'max_depth': 2, 'min_samples_split': 7, 'min_samples_leaf': 5, 'subsample': 0.5195038591034954}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:13:55,777] Trial 4 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 5, 'learning_rate': 0.06436211041634007, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 7, 'subsample': 0.6842012210041171}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:14:09,640] Trial 5 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 3, 'learning_rate': 0.0017568953891855233, 'max_depth': 2, 'min_samples_split': 18, 'min_samples_leaf': 20, 'subsample': 0.8306315969816254}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:14:26,692] Trial 6 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 5, 'learning_rate': 0.017154566672282753, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 15, 'subsample': 0.5996724876438302}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:14:42,541] Trial 7 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 5, 'learning_rate': 0.014227092017732836, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 5, 'subsample': 0.6320593527552915}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:14:55,909] Trial 8 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 3, 'learning_rate': 0.0019379725823430306, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 18, 'subsample': 0.9588273196208388}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:15:08,162] Trial 9 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 2, 'learning_rate': 0.10395083497016534, 'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 15, 'subsample': 0.5701219416600037}. Best is trial 0 with value: 0.7692310560998259.
# [I 2025-10-19 21:15:21,355] Trial 10 finished with value: 0.9718423103745334 and parameters: {'n_estimators': 4, 'learning_rate': 0.2744713815903884, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 1, 'subsample': 0.7518360965335972}. Best is trial 10 with value: 0.9718423103745334.
# [I 2025-10-19 21:15:35,335] Trial 11 finished with value: 0.7692310560998259 and parameters: {'n_estimators': 4, 'learning_rate': 0.04640309463979599, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 1, 'subsample': 0.7616151640415949}. Best is trial 10 with value: 0.9718423103745334.
# [I 2025-10-19 21:15:49,267] Trial 12 finished with value: 0.9719840236884993 and parameters: {'n_estimators': 4, 'learning_rate': 0.2756120422569732, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 1, 'subsample': 0.7137796201151613}. Best is trial 12 with value: 0.9719840236884993.
# [I 2025-10-19 21:16:14,778] Trial 13 finished with value: 0.9727843309826326 and parameters: {'n_estimators': 4, 'learning_rate': 0.2930881809002319, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 1, 'subsample': 0.730949719311211}. Best is trial 13 with value: 0.9727843309826326.
# [I 2025-10-19 21:16:40,268] Trial 14 finished with value: 0.9675275128940468 and parameters: {'n_estimators': 4, 'learning_rate': 0.29618167457980604, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 4, 'subsample': 0.6873303221032742}. Best is trial 13 with value: 0.9727843309826326.
# Nombre d’essais : 15
# Meilleur score : 0.9727843309826326
# Meilleurs hyperparamètres : {'n_estimators': 4, 'learning_rate': 0.2930881809002319, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 1, 'subsample': 0.730949719311211}

# %%
best_model = XGBClassifier(**study.best_params, random_state=42)
best_model.fit(X_train_smote, y_train_smote)
y_pred = best_model.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
print(f"✅ Accuracy du Gradient Boosting : {acc:.4f}\n")


print("📊 Report of classifier :")
y_pred_base_new = xgb.predict(X_test)
y_pred_proba_base_new = xgb.predict_proba(X_test)[:,1]

print(f"F1-Score:          {f1_score(y_test, y_pred_base_new)*100:.4f} %")
print(f"Precision:         {precision_score(y_test, y_pred_base_new)*100:.4f} %")
print(f"Recall:            {recall_score(y_test, y_pred_base_new)*100:.4f} %")
print(f"ROC-AUC:           {roc_auc_score(y_test, y_pred_proba_base_new)*100:.4f} %")
print(f"PR-AUC:            {average_precision_score(y_test, y_pred_proba_base_new)*100:.4f} %")
# Out:
# ✅ Accuracy du Gradient Boosting : 0.9954
#
# 📊 Report of classifier :
# F1-Score:          49.8494 %
# Precision:         35.6814 %
# Recall:            82.6782 %
# ROC-AUC:           98.5741 %
# PR-AUC:            71.2617 %

# %%
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Matrice de confusion - Gradient Boosting")
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.show()
